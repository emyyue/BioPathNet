# %%
library(data.table)
library(patchwork)
library(ggplot2)
library(patchwork)
library(purrr)
library(ggthemes)
library(dplyr)
library(grid)
# Out:
# Attache Paket: 'purrr'
#
#
# Das folgende Objekt ist maskiert 'package:data.table':
#
#     transpose
#
#
#
# Attache Paket: 'dplyr'
#
#
# Die folgenden Objekte sind maskiert von 'package:data.table':
#
#     between, first, last
#
#
# Die folgenden Objekte sind maskiert von 'package:stats':
#
#     filter, lag
#
#
# Die folgenden Objekte sind maskiert von 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
data <- fread("results/txgnn_biokgc_all_metrics.csv")

# %%
plot_metric <- function(x_metric, y_disease_area="cell_proliferation", cols=cols){
    pd = position_jitterdodge(dodge.width = 0.4, jitter.width = 0.4)
    plt <- ggplot(data[metric==x_metric][disease_area%in%y_disease_area], aes(y=mean, x=rel, fill=model)) +
    geom_boxplot(alpha=0.6, outlier.shape = NA, width=0.4)+ geom_point(aes(color = model),position = pd) +#
    scale_fill_manual(values = cols) + 
    scale_colour_manual(values = cols) + 
    labs(title=gsub("_", " ", x_metric), x="", y="") + 
    guides(color=guide_legend(title="Model"), fill=guide_legend(title="Model")) + 
    theme_bw()+
    #facet_wrap(.~disease_area, scales="free") +
    theme(text = element_text(size=18), axis.text.x = element_text(size = 12, angle=0, hjust=0.5))
    return(plt)
}

get_std <- function(x_metric, y_disease_area){
    stat = data[metric==x_metric][disease_area==y_disease_area][,.(mean, model, rel)]
    diff = as.data.table(data_summary(stat, varname="mean", 
                        groupnames=c("model", "rel")))
    diff[,disease_area:=y_disease_area]
    return(diff)
}

data_summary <- function(data, varname, groupnames){
  require(plyr)
  summary_func <- function(x, col){
    c(mean = mean(x[[col]], na.rm=TRUE),
      sd = sd(x[[col]], na.rm=TRUE))
  }
  data_sum<-ddply(data, groupnames, .fun=summary_func,
                  varname)
  #data_sum <- rename(data_sum, c("median" = varname))
 return(data_sum)
}

get_diff <- function(x_metric, y_disease_area){
    stat = data[metric==x_metric][disease_area==y_disease_area][,mean(mean), by=.(model, rel)]
    diff = stat[model==newname_nbfnet][,.(V1)] - stat[model=="TxGNN"][,.(V1)]
    diff[,relation:=c("contra\nindication", "indication")]
    diff[,disease_area:=y_disease_area]
    return(diff)
}

# %%
# functions for plot of difference with mad
get_std_on_diff <- function(x_metric){
    base = data[metric==x_metric][model=="TxGNN"][order(disease_area, seed, rel)]
    base$diff = (data[metric==x_metric][model==newname_nbfnet][order(disease_area, seed, rel)]$mean) - 
        (data[metric==x_metric][model=="TxGNN"][order(disease_area, seed, rel)]$mean)
    return(base[,.(metric, diff, seed, rel, disease_area)])
}

get_std_wo_model <- function(x_metric, y_disease_area, data=base_data){
    stat = data[disease_area==y_disease_area][,.(diff, rel)]
    diff = as.data.table(data_summary(stat, varname="diff", 
                        groupnames=c("rel")))
    diff[,disease_area:=y_disease_area]
    return(diff)
}

# %%
plot_summary_stats <- function(dis){
    mycol = col_dict[disease==dis, color]
    print(mycol)
    mypalette=c("#c6c6c6", mycol)
    print(mypalette)
    spec = plot_metric("Specificity", dis, mypalette) + theme(legend.position="none")
    sens = plot_metric("Sensitivity", dis, mypalette)+ theme(legend.position="none")
    #ap_all = plot_metric("AUPRC_ALL") + theme(legend.position="none")
    ap = plot_metric("AUPRC", dis, mypalette)+ theme(legend.position="none")
    ap_one = plot_metric("AUPRC_1:1", dis, mypalette)+ theme(legend.position="none")
    f1 = plot_metric("F1", dis, mypalette)+ theme(legend.position="none")
    fdr = plot_metric("FPR", dis, mypalette)+ theme(legend.position="none")
    fnr = plot_metric("FNR", dis, mypalette)+ theme(legend.position="none")
    mrr = plot_metric("MRR@20", dis, mypalette)+ theme(legend.position="none")
    ap_20 = plot_metric("AP@20", dis, mypalette)+ theme(legend.position="none")

    options(repr.plot.width = 12, repr.plot.height = 8)

    plt = (ap +ap_one + mrr + ap_20 +sens + fdr + spec + fnr  + plot_layout(ncol = 4))
    return(plt)
}

# %%
col_dict = as.data.table(cbind(hcl.colors(palette = "Sunset", n=5),
c("adrenal_gland", "anemia", "cardiovascular", "cell_proliferation", "mental_health")))
colnames(col_dict) <- c("color", "disease")
col_dict
# Out:
#   color   disease
# 1 #704D9E adrenal_gland
# 2 #BC5AA9 anemia
# 3 #ED7C97 cardiovascular
# 4 #F9B282 cell_proliferation
# 5 #F3E79A mental_health

# %%
mycols=c(rbind("#c6c6c6", hcl.colors(palette = "Sunset", n=5)))
mylevels= as.character(unique(data_std$rel_dis))
cbind(mylevels,mycols)
# Out:
# Error in unique(data_std$rel_dis): Objekt 'data_std' nicht gefunden
# Traceback:
#
# 1. unique(data_std$rel_dis)

# %%
options(repr.plot.width = 10, repr.plot.height = 5)
cols=c("#c6c6c6", "#56B4E9")
mymetric="AUPRC"
data_std = rbind(get_std(mymetric, "anemia"), get_std(mymetric, "adrenal_gland"), get_std(mymetric, "cardiovascular"),
      get_std(mymetric, "cell_proliferation"), get_std(mymetric, "mental_health"))

data_std$disease_area <- gsub("_", " ", data_std$disease_area)
data_std[, rel_dis:=paste0(model, "_", disease_area)]
data_std$rel_dis = factor(data_std$rel_dis, levels=unique(data_std$rel_dis))

data_std$rel=as.factor(data_std$rel)
auprc_bar_2 = ggplot(data_std, aes(x=disease_area, y=mean, fill=rel_dis)) + 
  geom_bar(stat="identity", color="black", 
           position=position_dodge(), width=0.5) +
  geom_errorbar(aes(ymin=mean-sd, ymax=mean+sd), width=.2,
                 position=position_dodge(.5)) +
  theme_bw() +
  facet_wrap(~rel, scales="free") +
  #facet_grid(rel~disease_area, scales="free") +
    #scale_fill_manual(values = cols) +
    scale_fill_manual(values = mycols) +
   theme(text = element_text(size=18), axis.text.x = element_text(size = 15, angle=30, hjust=1))+
       labs( x="", y="AUPRC") + 
       theme(legend.position="none")+
    guides(fill=guide_legend(title="Model"));auprc_bar_2

  data_std$rel=as.factor(data_std$rel)
auprc_bar = ggplot(data_std, aes(x=disease_area, y=mean, fill=model)) + 
  geom_bar(stat="identity", color="black", 
           position=position_dodge(), width=0.5) +
  geom_errorbar(aes(ymin=mean-sd, ymax=mean+sd), width=.2,
                 position=position_dodge(.5)) +
  theme_bw() +
  facet_wrap(~rel, scales="free") +
  #facet_grid(rel~disease_area, scales="free") +
    scale_fill_manual(values = cols) +
    #coord_cartesian(ylim=c(0.5, 0.9))+
   theme(text = element_text(size=18), axis.text.x = element_text(size = 15, angle=30, hjust=1))+
       labs( x="", y="AUPRC") + 
    guides(fill=guide_legend(title="Model"));auprc_bar
# Out:
# Lade n"otiges Paket: plyr
# ------------------------------------------------------------------------------
#
# You have loaded plyr after dplyr - this is likely to cause problems.
# If you need functions from both plyr and dplyr, please load plyr first, then dplyr:
# library(plyr); library(dplyr)
#
# ------------------------------------------------------------------------------
#
#
# Attache Paket: 'plyr'
#
#
# Die folgenden Objekte sind maskiert von 'package:dplyr':
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
#
# Das folgende Objekt ist maskiert 'package:purrr':
#
#     compact
# plot without title
# plot without title

# %%
data_std
# Out:
#    model  rel                mean       sd          disease_area
# 1  TxGNN  contra\nindication 0.37856820 0.039814095 anemia
# 2  TxGNN  indication         0.32551615 0.039858827 anemia
# 3  BioKGC contra\nindication 0.42608782 0.021066410 anemia
# 4  BioKGC indication         0.39696296 0.045859138 anemia
# 5  TxGNN  contra\nindication 0.69526775 0.017506368 adrenal gland
# 6  TxGNN  indication         0.56810695 0.019459967 adrenal gland
# 7  BioKGC contra\nindication 0.64849711 0.043760301 adrenal gland
# 8  BioKGC indication         0.79388143 0.033456203 adrenal gland
# 9  TxGNN  contra\nindication 0.13919408 0.003214647 cardiovascular
# 10 TxGNN  indication         0.07632014 0.007481034 cardiovascular
# 11 BioKGC contra\nindication 0.13740978 0.020025608 cardiovascular
# 12 BioKGC indication         0.13511534 0.004820318 cardiovascular
# 13 TxGNN  contra\nindication 0.49562967 0.008667927 cell proliferation
# 14 TxGNN  indication         0.37799121 0.016193484 cell proliferation
# 15 BioKGC contra\nindication 0.58531949 0.042188823 cell proliferation
# 16 BioKGC indication         0.52662579 0.034881025 cell proliferation
# 17 TxGNN  contra\nindication 0.17276659 0.008118638 mental health
# 18 TxGNN  indication         0.14653066 0.018565578 mental health
# 19 BioKGC contra\nindication 0.15204605 0.027065538 mental health
# 20 BioKGC indication         0.22173152 0.013617928 mental health
#    rel_dis
# 1  TxGNN_anemia
# 2  TxGNN_anemia
# 3  BioKGC_anemia
# 4  BioKGC_anemia
# 5  TxGNN_adrenal gland
# 6  TxGNN_adrenal gland
# 7  BioKGC_adrenal gland
# 8  BioKGC_adrenal gland
# 9  TxGNN_cardiovascular
# 10 TxGNN_cardiovascular
# 11 BioKGC_cardiovascular
# 12 BioKGC_cardiovascular
# 13 TxGNN_cell proliferation
# 14 TxGNN_cell proliferation
# 15 BioKGC_cell proliferation
# 16 BioKGC_cell proliferation
# 17 TxGNN_mental health
# 18 TxGNN_mental health
# 19 BioKGC_mental health
# 20 BioKGC_mental health

# %%
base_data = get_std_on_diff("AUPRC")
base_data_plt = rbind(get_std_wo_model(mymetric, "anemia", base_data), get_std_wo_model(mymetric, "adrenal_gland", base_data), get_std_wo_model(mymetric, "cardiovascular", base_data),
      get_std_wo_model(mymetric, "cell_proliferation", base_data), get_std_wo_model(mymetric, "mental_health", base_data))

# %%
options(repr.plot.width = 7, repr.plot.height = 5)

base_data_plt$disease_area <- gsub("_", " ", base_data_plt$disease_area)

custom_x=1.54
custom_y=0.02
grob =   grobTree(textGrob(paste0(newname_nbfnet, " is better"), x=0.15,  y=0.95, hjust=0,
  gp=gpar(col="#dd2d4a", fontsize=13))) 
grob2 = grobTree(textGrob("TxGNN is better", x=0.19,  y=0.05, hjust=0,
  gp=gpar(col="#dd2d4a", fontsize=13))) 
base_data_plt$rel=as.factor(base_data_plt$rel)
diff_auprc = ggplot(base_data_plt, aes(x=rel, y=mean, fill=disease_area)) + 
  geom_bar(stat="identity", color="black", 
           position=position_dodge(), width=1) +
  geom_errorbar(aes(ymin=mean-sd, ymax=mean+sd), width=.2,
                 position=position_dodge(1)) +
  theme_bw() +
  #facet_wrap(~rel, scales="free") +
  #facet_grid(rel~disease_area, scales="free") +
  scale_fill_manual(values = c('#704D9E','#BC5AA9','#ED7C97','#F9B282','#F3E79A')) +

  # line at 0
  geom_hline(yintercept=0,  color = "#dd2d4a", size=1) +

  # add text
  annotation_custom(grob) + annotation_custom(grob2) +
geom_segment(aes(x = custom_x, y = custom_y, xend = custom_x, yend = 0.3),
                  arrow = arrow(length = unit(0.5, "cm")),col="#dd2d4a")+
geom_segment(aes(x = custom_x, y = -custom_y, xend = custom_x, yend = -0.1),
                  arrow = arrow(length = unit(0.5, "cm")),col="#dd2d4a")+

  theme(text = element_text(size=18), axis.text.x=element_blank(), axis.ticks.x=element_blank())+ #axis.text.x = element_text(size = 15, angle=0, hjust=0.5),)+
  labs( x="", y="difference in AUPRC") + 
  facet_wrap(~rel, scales="free") +
  guides(fill=guide_legend(title="Disease\narea"));diff_auprc
# Out:
# Warning message:
# "Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# i Please use `linewidth` instead."
# plot without title

# %%
base_data_plt[, mean_100 := mean]
base_data_plt[rel=="indication"]
base_data_plt[rel=="contra\nindication"]
# Out:
#   rel        mean       sd          disease_area       mean_100
# 1 indication 0.07144680 0.055780901 anemia             0.07144680
# 2 indication 0.22577448 0.047184816 adrenal gland      0.22577448
# 3 indication 0.05879520 0.004989336 cardiovascular     0.05879520
# 4 indication 0.14863458 0.036101799 cell proliferation 0.14863458
# 5 indication 0.07520086 0.016361990 mental health      0.07520086
#   rel                mean         sd         disease_area       mean_100
# 1 contra\nindication  0.047519625 0.02678059 anemia              0.047519625
# 2 contra\nindication -0.046770644 0.03809345 adrenal gland      -0.046770644
# 3 contra\nindication -0.001784301 0.01895644 cardiovascular     -0.001784301
# 4 contra\nindication  0.089689826 0.04457880 cell proliferation  0.089689826
# 5 contra\nindication -0.020720537 0.03471692 mental health      -0.020720537

# %%
data[metric_x=="Recall"][is.na(perc)]
# Out:
#     V1 idx metric     mean        std         model  rel
# 1   27 27  Recall@1   0.007945906 0.005060954 TxGNN  contra\nindication
# 2   32 32  Recall@10  0.204459055 0.171963838 TxGNN  contra\nindication
# 3   37 37  Recall@20  0.325584777 0.201509135 TxGNN  contra\nindication
# 4   42 42  Recall@30  0.446710499 0.232242208 TxGNN  contra\nindication
# 5   47 47  Recall@40  0.526169554 0.196869961 TxGNN  contra\nindication
# 6   52 52  Recall@50  0.605628609 0.169415969 TxGNN  contra\nindication
# 7   57 57  Recall@100 0.794616519 0.135530294 TxGNN  contra\nindication
# 8   27 27  Recall@1   0.054166667 0.054803943 TxGNN  indication
# 9   32 32  Recall@10  0.855555556 0.237788162 TxGNN  indication
# 10  37 37  Recall@20  0.855555556 0.237788162 TxGNN  indication
# 11  42 42  Recall@30  0.872222222 0.243749011 TxGNN  indication
# 12  47 47  Recall@40  0.872222222 0.243749011 TxGNN  indication
# 13  52 52  Recall@50  1.000000000 0.000000000 TxGNN  indication
# 14  57 57  Recall@100 1.000000000 0.000000000 TxGNN  indication
# 15  27 27  Recall@1   0.049612572 0.067614997 BioKGC contra\nindication
# 16  32 32  Recall@10  0.198725539 0.174839809 BioKGC contra\nindication
# 17  37 37  Recall@20  0.278184594 0.133850256 BioKGC contra\nindication
# 18  42 42  Recall@30  0.354122523 0.100323839 BioKGC contra\nindication
# 19  47 47  Recall@40  0.427848062 0.083051890 BioKGC contra\nindication
# 20  52 52  Recall@50  0.493627695 0.087273854 BioKGC contra\nindication
# 21  57 57  Recall@100 0.650333416 0.157719877 BioKGC contra\nindication
# 22  27 27  Recall@1   0.387500000 0.434873066 BioKGC indication
# 23  32 32  Recall@10  0.855555556 0.237788162 BioKGC indication
# 24  37 37  Recall@20  0.855555556 0.237788162 BioKGC indication
# 25  42 42  Recall@30  0.855555556 0.237788162 BioKGC indication
# 26  47 47  Recall@40  0.855555556 0.237788162 BioKGC indication
# 27  52 52  Recall@50  0.855555556 0.237788162 BioKGC indication
# 28  57 57  Recall@100 0.872222222 0.243749011 BioKGC indication
# 29  27 27  Recall@1   0.007945906 0.005060954 TxGNN  contra\nindication
# 30  32 32  Recall@10  0.162792389 0.100754568 TxGNN  contra\nindication
# <U+22EE>   <U+22EE> <U+22EE> <U+22EE>   <U+22EE>    <U+22EE>    <U+22EE> <U+22EE>
# 671 52 52  Recall@50  0.420571047 0.35656520  BioKGC indication
# 672 57 57  Recall@100 0.514223876 0.37083107  BioKGC indication
# 673 27 27  Recall@1   0.028731535 0.10475576  TxGNN  contra\nindication
# 674 32 32  Recall@10  0.100101258 0.23614970  TxGNN  contra\nindication
# 675 37 37  Recall@20  0.123683495 0.25349538  TxGNN  contra\nindication
# 676 42 42  Recall@30  0.161840144 0.26512117  TxGNN  contra\nindication
# 677 47 47  Recall@40  0.214480056 0.29710544  TxGNN  contra\nindication
# 678 52 52  Recall@50  0.248248980 0.32126433  TxGNN  contra\nindication
# 679 57 57  Recall@100 0.417077004 0.36301883  TxGNN  contra\nindication
# 680 27 27  Recall@1   0.008029008 0.02793843  TxGNN  indication
# 681 32 32  Recall@10  0.095606801 0.18925802  TxGNN  indication
# 682 37 37  Recall@20  0.185009652 0.24570363  TxGNN  indication
# 683 42 42  Recall@30  0.236269938 0.29791839  TxGNN  indication
# 684 47 47  Recall@40  0.313859788 0.32887503  TxGNN  indication
# 685 52 52  Recall@50  0.335852674 0.33123712  TxGNN  indication
# 686 57 57  Recall@100 0.515570677 0.38725255  TxGNN  indication
# 687 27 27  Recall@1   0.022914573 0.14569751  BioKGC contra\nindication
# 688 32 32  Recall@10  0.073918431 0.17850423  BioKGC contra\nindication
# 689 37 37  Recall@20  0.152198707 0.24972012  BioKGC contra\nindication
# 690 42 42  Recall@30  0.177432654 0.25877138  BioKGC contra\nindication
# 691 47 47  Recall@40  0.210183463 0.27279838  BioKGC contra\nindication
# 692 52 52  Recall@50  0.227219338 0.27592435  BioKGC contra\nindication
# 693 57 57  Recall@100 0.380604322 0.36772303  BioKGC contra\nindication
# 694 27 27  Recall@1   0.042064063 0.11239441  BioKGC indication
# 695 32 32  Recall@10  0.186836642 0.27949117  BioKGC indication
# 696 37 37  Recall@20  0.264885606 0.32390810  BioKGC indication
# 697 42 42  Recall@30  0.294468076 0.32111239  BioKGC indication
# 698 47 47  Recall@40  0.299961472 0.32006513  BioKGC indication
# 699 52 52  Recall@50  0.309320446 0.31918618  BioKGC indication
# 700 57 57  Recall@100 0.389391671 0.34177158  BioKGC indication
#     metric_x k   perc seed disease_area
# 1   Recall   1   NA     42 adrenal_gland
# 2   Recall   10  NA     42 adrenal_gland
# 3   Recall   20  NA     42 adrenal_gland
# 4   Recall   30  NA     42 adrenal_gland
# 5   Recall   40  NA     42 adrenal_gland
# 6   Recall   50  NA     42 adrenal_gland
# 7   Recall   100 NA     42 adrenal_gland
# 8   Recall   1   NA     42 adrenal_gland
# 9   Recall   10  NA     42 adrenal_gland
# 10  Recall   20  NA     42 adrenal_gland
# 11  Recall   30  NA     42 adrenal_gland
# 12  Recall   40  NA     42 adrenal_gland
# 13  Recall   50  NA     42 adrenal_gland
# 14  Recall   100 NA     42 adrenal_gland
# 15  Recall   1   NA     42 adrenal_gland
# 16  Recall   10  NA     42 adrenal_gland
# 17  Recall   20  NA     42 adrenal_gland
# 18  Recall   30  NA     42 adrenal_gland
# 19  Recall   40  NA     42 adrenal_gland
# 20  Recall   50  NA     42 adrenal_gland
# 21  Recall   100 NA     42 adrenal_gland
# 22  Recall   1   NA     42 adrenal_gland
# 23  Recall   10  NA     42 adrenal_gland
# 24  Recall   20  NA     42 adrenal_gland
# 25  Recall   30  NA     42 adrenal_gland
# 26  Recall   40  NA     42 adrenal_gland
# 27  Recall   50  NA     42 adrenal_gland
# 28  Recall   100 NA     42 adrenal_gland
# 29  Recall   1   NA   2011 adrenal_gland
# 30  Recall   10  NA   2011 adrenal_gland
# <U+22EE>   <U+22EE> <U+22EE> <U+22EE> <U+22EE> <U+22EE>
# 671 Recall   50  NA     88 mental_health
# 672 Recall   100 NA     88 mental_health
# 673 Recall   1   NA   1618 mental_health
# 674 Recall   10  NA   1618 mental_health
# 675 Recall   20  NA   1618 mental_health
# 676 Recall   30  NA   1618 mental_health
# 677 Recall   40  NA   1618 mental_health
# 678 Recall   50  NA   1618 mental_health
# 679 Recall   100 NA   1618 mental_health
# 680 Recall   1   NA   1618 mental_health
# 681 Recall   10  NA   1618 mental_health
# 682 Recall   20  NA   1618 mental_health
# 683 Recall   30  NA   1618 mental_health
# 684 Recall   40  NA   1618 mental_health
# 685 Recall   50  NA   1618 mental_health
# 686 Recall   100 NA   1618 mental_health
# 687 Recall   1   NA   1618 mental_health
# 688 Recall   10  NA   1618 mental_health
# 689 Recall   20  NA   1618 mental_health
# 690 Recall   30  NA   1618 mental_health
# 691 Recall   40  NA   1618 mental_health
# 692 Recall   50  NA   1618 mental_health
# 693 Recall   100 NA   1618 mental_health
# 694 Recall   1   NA   1618 mental_health
# 695 Recall   10  NA   1618 mental_health
# 696 Recall   20  NA   1618 mental_health
# 697 Recall   30  NA   1618 mental_health
# 698 Recall   40  NA   1618 mental_health
# 699 Recall   50  NA   1618 mental_health
# 700 Recall   100 NA   1618 mental_health

# %%
plot_k_plots <- function(mymetric){
   plt_data_recall = data[metric_x==mymetric][(is.na(perc))][k!=100]
   nrow(plt_data_recall)
   plt_data_recall$model <- factor(plt_data_recall$model, c("TxGNN", newname_nbfnet))
   plt_data_recall$k <- as.integer(plt_data_recall$k)
   plt_data_recall$seed <- as.factor(plt_data_recall$seed)
   plt_data_recall[,.N, by=k]
   plt_data_recall[, model_seed:=paste0(model, '-', seed)]
   options(repr.plot.width = 8, repr.plot.height = 4)

   pd = position_jitterdodge(dodge.width = 0.4, jitter.width = 0)

   cols= c("#c6c6c6","#E87519")
   plt3 = ggplot(plt_data_recall[disease_area=="cell_proliferation"], aes(x=k, y=mean, color=model)) + 
   #geom_boxplot(alpha=0.9, outlier.shape = NA, width=0.4)+
   geom_point(aes(color = model),position = pd) +
      scale_fill_manual(values = cols) + 
      scale_colour_manual(values = cols) + 
      labs(title=paste0(mymetric,"@k"), x="k", y="") + 
      theme_bw()+
      stat_summary(
      fun = mean,
      geom = 'line',
      aes(group = model, colour = model),
      position = pd )+ #this has to be added
      facet_grid(.~rel)+
   #       facet_wrap(~rel, scales="free") +

      theme(text = element_text(size=20), axis.text.x = element_text(angle=0, hjust=0.5))+ 
      theme(legend.position="right")
      return(plt3)
}


#plot_k_plots("MRR")
#plot_k_plots("AP")
plot_k_plots("Recall")
# Out:
# plot without title

# %%
plt3 = plot_k_plots("Recall")

# %% [markdown]
# The increase expressed as percentage

# %%
df_mean = data[,mean(mean), by=.(model, disease_area, rel, metric)][disease_area%in%"cell_proliferation"][metric%in%c("AUPRC", "Specificity", "F1", "Recall@10")]
df_mean %>%
    group_by(metric, rel) %>%
    mutate(deltaC = ((V1 - V1[model == 'TxGNN'])/V1[model == 'TxGNN'])*100)
# Out:
#    model  disease_area       rel                metric      V1
# 1  TxGNN  cell_proliferation contra\nindication AUPRC       0.4956297
# 2  TxGNN  cell_proliferation contra\nindication Specificity 0.9908523
# 3  TxGNN  cell_proliferation contra\nindication F1          0.3295711
# 4  TxGNN  cell_proliferation contra\nindication Recall@10   0.4359666
# 5  TxGNN  cell_proliferation indication         AUPRC       0.3779912
# 6  TxGNN  cell_proliferation indication         Specificity 0.9793158
# 7  TxGNN  cell_proliferation indication         F1          0.1830720
# 8  TxGNN  cell_proliferation indication         Recall@10   0.4165339
# 9  BioKGC cell_proliferation contra\nindication AUPRC       0.5853195
# 10 BioKGC cell_proliferation contra\nindication Specificity 0.9958987
# 11 BioKGC cell_proliferation contra\nindication F1          0.4154386
# 12 BioKGC cell_proliferation contra\nindication Recall@10   0.5040063
# 13 BioKGC cell_proliferation indication         AUPRC       0.5266258
# 14 BioKGC cell_proliferation indication         Specificity 0.9956642
# 15 BioKGC cell_proliferation indication         F1          0.3919233
# 16 BioKGC cell_proliferation indication         Recall@10   0.5378641
#    deltaC
# 1    0.0000000
# 2    0.0000000
# 3    0.0000000
# 4    0.0000000
# 5    0.0000000
# 6    0.0000000
# 7    0.0000000
# 8    0.0000000
# 9   18.0961374
# 10   0.5093036
# 11  26.0543291
# 12  15.6066213
# 13  39.3222310
# 14   1.6693671
# 15 114.0815104
# 16  29.1285083

# %%
df_mean = data[,mean(mean), by=.(model, disease_area, rel, metric)][disease_area%in%"cell_proliferation"][metric%in%c("AUPRC", "Specificity", "F1", "Recall@20")]
df_mean %>%
    group_by(metric, rel) %>%
    mutate(deltaC = ((V1 - V1[model == 'TxGNN'])/V1[model == 'TxGNN'])*100)
# Out:
#    model  disease_area       rel                metric      V1
# 1  TxGNN  cell_proliferation contra\nindication AUPRC       0.4956297
# 2  TxGNN  cell_proliferation contra\nindication Specificity 0.9908523
# 3  TxGNN  cell_proliferation contra\nindication F1          0.3295711
# 4  TxGNN  cell_proliferation contra\nindication Recall@20   0.5386764
# 5  TxGNN  cell_proliferation indication         AUPRC       0.3779912
# 6  TxGNN  cell_proliferation indication         Specificity 0.9793158
# 7  TxGNN  cell_proliferation indication         F1          0.1830720
# 8  TxGNN  cell_proliferation indication         Recall@20   0.5385465
# 9  BioKGC cell_proliferation contra\nindication AUPRC       0.5853195
# 10 BioKGC cell_proliferation contra\nindication Specificity 0.9958987
# 11 BioKGC cell_proliferation contra\nindication F1          0.4154386
# 12 BioKGC cell_proliferation contra\nindication Recall@20   0.5894852
# 13 BioKGC cell_proliferation indication         AUPRC       0.5266258
# 14 BioKGC cell_proliferation indication         Specificity 0.9956642
# 15 BioKGC cell_proliferation indication         F1          0.3919233
# 16 BioKGC cell_proliferation indication         Recall@20   0.6190318
#    deltaC
# 1    0.0000000
# 2    0.0000000
# 3    0.0000000
# 4    0.0000000
# 5    0.0000000
# 6    0.0000000
# 7    0.0000000
# 8    0.0000000
# 9   18.0961374
# 10   0.5093036
# 11  26.0543291
# 12   9.4321487
# 13  39.3222310
# 14   1.6693671
# 15 114.0815104
# 16  14.9449059

# %%
options(repr.plot.width = 15, repr.plot.height = 9)

pt = ((auprc_bar +  diff_auprc + plot_layout(width = c(6, 4.5)))/
        (ap + spec +f1 + plt3 + plot_layout(width = c(1,1,1,2.35))) ) + plot_layout(height = c(1,0.8))
pt# + plot_annotation(tag_levels = c('A')) &  theme(plot.tag.position = c(0, 0.955),plot.tag = element_text(size = 20, hjust = 0, vjust = 0))

pdf(paste0("//Users/yue.hu/Documents/proj/functionalannotation/analysis/perf/notebook/figs/",Sys.Date(),"BioKGC_fig_performances.pdf"), width=15, height=9)
pt
dev.off()
# Out:
# pdf
#   2
# plot without title

# %%
data[disease_area=="cell_proliferation"][metric=="Recall@10"][rel=="indication"][model==newname_nbfnet]
# Out:
#   V1 idx metric    mean      std       model  rel        metric_x k  perc seed
# 1 32 32  Recall@10 0.5539758 0.4130250 BioKGC indication Recall   10 NA     42
# 2 32 32  Recall@10 0.5119017 0.4086042 BioKGC indication Recall   10 NA   2011
# 3 32 32  Recall@10 0.5508640 0.4161464 BioKGC indication Recall   10 NA     14
# 4 32 32  Recall@10 0.5486504 0.4159456 BioKGC indication Recall   10 NA     88
# 5 32 32  Recall@10 0.5239285 0.4264396 BioKGC indication Recall   10 NA    314
#   disease_area
# 1 cell_proliferation
# 2 cell_proliferation
# 3 cell_proliferation
# 4 cell_proliferation
# 5 cell_proliferation

# %%
data[metric=="AUPRC"][model==newname_nbfnet][rel=="indication"]
# Out:
#   V1 idx metric mean      std       model  rel        metric_x k perc seed
# 1 1  1   AUPRC  0.5440024 0.4066063 NBFNet indication AUPRC      NA     42
# 2 1  1   AUPRC  0.4746708 0.4001615 NBFNet indication AUPRC      NA   2011
# 3 1  1   AUPRC  0.5303602 0.4042682 NBFNet indication AUPRC      NA     14
# 4 1  1   AUPRC  0.5682762 0.4254797 NBFNet indication AUPRC      NA     88
# 5 1  1   AUPRC  0.2441338 0.3249201 NBFNet indication AUPRC      NA   1618

# %%
data[metric=="AUPRC"][model==newname_nbfnet][rel=="indication"][disease_area=="cell_proliferation"]
# Out:
#   V1 idx metric mean      std       model  rel        metric_x k perc seed
# 1 1  1   AUPRC  0.5440024 0.4066063 BioKGC indication AUPRC      NA     42
# 2 1  1   AUPRC  0.4746708 0.4001615 BioKGC indication AUPRC      NA   2011
# 3 1  1   AUPRC  0.5303602 0.4042682 BioKGC indication AUPRC      NA     14
# 4 1  1   AUPRC  0.5682762 0.4254797 BioKGC indication AUPRC      NA     88
# 5 1  1   AUPRC  0.5158193 0.4167414 BioKGC indication AUPRC      NA    314
#   disease_area
# 1 cell_proliferation
# 2 cell_proliferation
# 3 cell_proliferation
# 4 cell_proliferation
# 5 cell_proliferation

# %% [markdown]
# ### Get averaged performances for contraindication and indication

# %%
get_std_all_diseaseArea <- function(mymetric){
      data_std = rbind(get_std(mymetric, "anemia"), get_std(mymetric, "adrenal_gland"), get_std(mymetric, "cardiovascular"),
      get_std(mymetric, "cell_proliferation"), get_std(mymetric, "mental_health"))
      return(data_std)
}

get_std_all_diseaseArea_average <- function(mymetric){
      data_std = rbind(get_std(mymetric, "anemia"), get_std(mymetric, "adrenal_gland"), get_std(mymetric, "cardiovascular"),
      get_std(mymetric, "cell_proliferation"), get_std(mymetric, "mental_health"))
      data_std = get_std_all_diseaseArea(mymetric)[, mean := mean(mean), by=.(model, disease_area)]
      data_std[, sd := mean(sd), by=.(model, disease_area)]
      data_std = unique(data_std[,.(model, mean, sd, disease_area)])
      data_std[,mean:=round(mean, 3)]
      data_std
      return(data_std)
}


get_std_all_diseaseArea_plot <- function(mymetric){
      data_std = get_std_all_diseaseArea(mymetric)[, mean := mean(mean), by=.(model, disease_area)]
      
      data_std[, sd := mean(sd), by=.(model, disease_area)]
      data_std = unique(data_std[,.(model, mean, sd, disease_area)])

      data_std$disease_area <- gsub("_", " ", data_std$disease_area)
      data_std[, rel_dis:=paste0(model, "_", disease_area)]
      data_std$rel_dis = factor(data_std$rel_dis, levels=unique(data_std$rel_dis))

      data_std$rel=as.factor(data_std$rel)

      data_std$rel=as.factor(data_std$rel)
      auprc_bar = ggplot(data_std, aes(x=disease_area, y=mean, fill=model)) + 
      geom_bar(stat="identity", color="black", 
            position=position_dodge(), width=0.5) +
      geom_errorbar(aes(ymin=mean-sd, ymax=mean+sd), width=.2,
                  position=position_dodge(.5)) +
      theme_bw() +
      #facet_wrap(~rel, scales="free") +
      #facet_grid(rel~disease_area, scales="free") +
      scale_fill_manual(values = cols) +
      #coord_cartesian(ylim=c(0.5, 0.9))+
      theme(text = element_text(size=18), axis.text.x = element_text(size = 15, angle=30, hjust=1))+
            labs( x="", y=mymetric) + 
      guides(fill=guide_legend(title="Model"))
      return(auprc_bar)
}

# %%
get_std_all_diseaseArea_average("AUPRC")

# %%
mymetrics <- c("Recall@20", "AP@20","MRR@20", "F1",  "AUPRC_1:1","AUPRC", "Accuracy")

df = rbindlist(lapply(mymetrics, get_std_all_diseaseArea_average),  idcol = "metric" )
df[, metric := factor(metric, labels = mymetrics)]
df_dcast = dcast(df, disease_area + model ~ metric, value.var = "mean")
df_dcast
# Out:
#    disease_area       model  Recall@20 AP@20 MRR@20 F1    AUPRC_1:1 AUPRC
# 1  adrenal_gland      TxGNN  0.604     0.724 0.725  0.612 0.587     0.632
# 2  adrenal_gland      BioKGC 0.562     0.903 0.900  0.405 0.582     0.721
# 3  anemia             TxGNN  0.450     0.457 0.535  0.244 0.667     0.352
# 4  anemia             BioKGC 0.504     0.493 0.520  0.305 0.674     0.412
# 5  cardiovascular     TxGNN  0.100     0.170 0.199  0.059 0.606     0.108
# 6  cardiovascular     BioKGC 0.166     0.230 0.249  0.074 0.605     0.136
# 7  cell_proliferation TxGNN  0.539     0.487 0.549  0.256 0.811     0.437
# 8  cell_proliferation BioKGC 0.604     0.626 0.654  0.404 0.813     0.556
# 9  mental_health      TxGNN  0.167     0.228 0.264  0.112 0.617     0.160
# 10 mental_health      BioKGC 0.219     0.265 0.297  0.132 0.570     0.187
#    Accuracy
# 1  0.986
# 2  0.971
# 3  0.975
# 4  0.979
# 5  0.962
# 6  0.976
# 7  0.983
# 8  0.992
# 9  0.955
# 10 0.977

# %% [markdown]
# ### How much better is BioKGC compared to TxGNN?

# %%
diff_all_metrics = cbind(df[model=="BioKGC"][,.(metric,disease_area)], (df[model=="BioKGC", mean] - df[model=="TxGNN", mean])*100)
dcast(diff_all_metrics, disease_area  ~ metric, value.var = "V2")
# Out:
#   disease_area       Recall@20 AP@20 MRR@20 F1    AUPRC_1:1 AUPRC Accuracy
# 1 adrenal_gland      -4.2      17.9  17.5   -20.7 -0.5       8.9  -1.5
# 2 anemia              5.4       3.6  -1.5     6.1  0.7       6.0   0.4
# 3 cardiovascular      6.6       6.0   5.0     1.5 -0.1       2.8   1.4
# 4 cell_proliferation  6.5      13.9  10.5    14.8  0.2      11.9   0.9
# 5 mental_health       5.2       3.7   3.3     2.0 -4.7       2.7   2.2

# %% [markdown]
# How much better if taking the sum: so how much is BioKGC better summed over contraindication and indication

# %%
diff_all_metrics = cbind(df[model=="BioKGC"][,.(metric,disease_area)], (df[model=="BioKGC", mean] - df[model=="TxGNN", mean])*100)
dcast(diff_all_metrics, disease_area  ~ metric, value.var = "V2")
# Out:
#   disease_area       Recall@20 AP@20 MRR@20 F1    AUPRC_1:1 AUPRC Accuracy
# 1 adrenal_gland      -4.2      17.9  17.5   -20.7 -0.5       8.9  -1.5
# 2 anemia              5.4       3.6  -1.5     6.1  0.7       6.0   0.4
# 3 cardiovascular      6.6       6.0   5.0     1.5 -0.1       2.8   1.4
# 4 cell_proliferation  6.5      13.9  10.5    14.8  0.2      11.9   0.9
# 5 mental_health       5.2       3.7   3.3     2.0 -4.7       2.7   2.2

# %%
df[disease_area=="cell_proliferation"][order(model)] %>%
    group_by(metric, model) %>%
    mutate(deltaC = ((mean - mean[model == 'TxGNN'])))
# Out:
#    metric    model  mean  sd          disease_area       deltaC
# 1  Recall@20 TxGNN  0.539 0.011896953 cell_proliferation 0.000
# 2  AP@20     TxGNN  0.487 0.013917098 cell_proliferation 0.000
# 3  MRR@20    TxGNN  0.549 0.018070843 cell_proliferation 0.000
# 4  F1        TxGNN  0.256 0.018846357 cell_proliferation 0.000
# 5  AUPRC_1:1 TxGNN  0.811 0.028256869 cell_proliferation 0.000
# 6  AUPRC     TxGNN  0.437 0.012430706 cell_proliferation 0.000
# 7  Accuracy  TxGNN  0.983 0.001344910 cell_proliferation 0.000
# 8  Recall@20 BioKGC 0.604 0.025483066 cell_proliferation 0.065
# 9  AP@20     BioKGC 0.626 0.035760873 cell_proliferation 0.139
# 10 MRR@20    BioKGC 0.654 0.035333783 cell_proliferation 0.105
# 11 F1        BioKGC 0.404 0.036083551 cell_proliferation 0.148
# 12 AUPRC_1:1 BioKGC 0.813 0.051202359 cell_proliferation 0.002
# 13 AUPRC     BioKGC 0.556 0.038534924 cell_proliferation 0.119
# 14 Accuracy  BioKGC 0.992 0.001880499 cell_proliferation 0.009

# %%
df[order(model)][metric=="AUPRC"] %>%
    group_by(metric, model) %>%
    mutate(deltaC = ((mean - mean[model == 'TxGNN'])/mean[model == 'TxGNN'])*100) %>% setDT  %>%
    .[model=="BioKGC"] %>% .$deltaC %>% mean
# Out:
# [1] 20.23196
